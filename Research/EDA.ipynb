# %% [markdown]
# # **(EDA NOTEBOOK)**

# %% [markdown]
# ## Objectives
#
# * Perform Exploratory Data Analysis on the cleaned Telco customer churn dadtaset to understand variable distributions
#
# ## Inputs
#
# * Cleaned Telco customer churn dataset - cleaned_telco.csv
#
# ## Outputs
#
# * Summary statistics and notes regarding values
#
# ## Additional Comments
#
# * These findings will aid feature engineering and modelling steps later in the project.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/isaacola/Documents/vscode-project/Data_Analytics_Capstone/Data-Analytics-Capstone/Research'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/isaacola/Documents/vscode-project/Data_Analytics_Capstone/Data-Analytics-Capstone'

# %% [markdown]
# # Section 1

# %% [markdown]
# # Explorative Data Analysis

# %%
# Import Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Cleaned Dataset
print("Loading cleaned dataset...")
df = pd.read_csv("../dataset/processed/cleaned_telco.csv")
# Out:
# Loading cleaned dataset...

# %%
#  Data Overview
print("First five rows:")
df.head()
# Out:
# First five rows:
#    gender  seniorcitizen  partner  dependents  tenure  phoneservice  \
# 0  Female              0        1           0       1             0
# 1    Male              0        0           0      34             1
# 2    Male              0        0           0       2             1
# 3    Male              0        0           0      45             0
# 4  Female              0        0           0       2             1
#
#       multiplelines internetservice onlinesecurity onlinebackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   techsupport streamingtv streamingmovies        contract paperlessbilling  \
# ...

# %%
# Display DataFrame info
print("Dataframe info:")
df.info()
# Out:
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7010 entries, 0 to 7009
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7010 non-null   object
#  1   seniorcitizen     7010 non-null   int64
#  2   partner           7010 non-null   int64
#  3   dependents        7010 non-null   int64
#  4   tenure            7010 non-null   int64
#  5   phoneservice      7010 non-null   int64
#  6   multiplelines     7010 non-null   object
#  7   internetservice   7010 non-null   object
#  8   onlinesecurity    7010 non-null   object
#  9   onlinebackup      7010 non-null   object
#  10  deviceprotection  7010 non-null   object
#  11  techsupport       7010 non-null   object
#  12  streamingtv       7010 non-null   object
#  13  streamingmovies   7010 non-null   object
#  14  contract          7010 non-null   object
#  15  paperlessbilling  7010 non-null   int64
# ...

# %%
# Statistical summary
df.describe(include="all")
# Out:
#        gender  seniorcitizen      partner   dependents       tenure  \
# count    7010    7010.000000  7010.000000  7010.000000  7010.000000
# unique      2            NaN          NaN          NaN          NaN
# top      Male            NaN          NaN          NaN          NaN
# freq     3535            NaN          NaN          NaN          NaN
# mean      NaN       0.162767     0.484023     0.299429    32.520399
# std       NaN       0.369180     0.499780     0.458041    24.520441
# min       NaN       0.000000     0.000000     0.000000     1.000000
# 25%       NaN       0.000000     0.000000     0.000000     9.000000
# 50%       NaN       0.000000     0.000000     0.000000    29.000000
# 75%       NaN       0.000000     1.000000     1.000000    56.000000
# max       NaN       1.000000     1.000000     1.000000    72.000000
#
#         phoneservice multiplelines internetservice onlinesecurity  \
# count    7010.000000          7010            7010           7010
# ...

# %%
# Check target variable distribution
df["churn"].value_counts()
# Out:
# churn
# 0    5153
# 1    1857
# Name: count, dtype: int64

# %% [markdown]
# ---
